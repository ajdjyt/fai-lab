# %%
#!pip install -qU  opendatasets pandas scikit-learn

# %%
kaggle_key="d782424c608cb7ac4f6fc916cc201333"

# %%
import json
kaggle_json = {"username":"arjofe", "key":kaggle_key}
with open("kaggle.json","w") as fh:
  fh.write(json.dumps(kaggle_json))

# %%
import opendatasets as od
# make sure to have kaggle.json in your working directory
od.download("https://www.kaggle.com/datasets/toramky/automobile-dataset", force = True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/toramky/automobile-dataset
# Downloading automobile-dataset.zip to ./automobile-dataset
# 100%|██████████| 4.87k/4.87k [00:00<00:00, 3.39MB/s]

# %%
import os 
os.listdir("automobile-dataset")
os.chdir("automobile-dataset")

# %%
import pandas as pd
df = pd.read_csv("Automobile_data.csv", na_values='?')
df = df.fillna(0)

# %%
df.head(3)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                0.0  alfa-romero       gas        std
# 1          3                0.0  alfa-romero       gas        std
# 2          1                0.0  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
#
# [3 rows x 26 columns]

# %%
n=len(df)

# %%
df["price"] = df["price"].astype('int64')
max_price = df["price"].max()

# %%
most_expensive_car_company_name = str(df[df["price"]==max_price].make)

# %%
print(most_expensive_car_company_name)
# Out:
# 74    mercedes-benz
# Name: make, dtype: object

# %%
## All toyota cars

df[df["make"]=="toyota"]
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 150          1               87.0  toyota       gas        std          two
# 151          1               87.0  toyota       gas        std          two
# 152          1               74.0  toyota       gas        std         four
# 153          0               77.0  toyota       gas        std         four
# 154          0               81.0  toyota       gas        std         four
# 155          0               91.0  toyota       gas        std         four
# 156          0               91.0  toyota       gas        std         four
# 157          0               91.0  toyota       gas        std         four
# 158          0               91.0  toyota    diesel        std         four
# 159          0               91.0  toyota    diesel        std         four
# 160          0               91.0  toyota       gas        std         four
# 161          0               91.0  toyota       gas        std         four
# 162          0               91.0  toyota       gas        std         four
# 163          1              168.0  toyota       gas        std          two
# 164          1              168.0  toyota       gas        std          two
# 165          1              168.0  toyota       gas        std          two
# 166          1              168.0  toyota       gas        std          two
# 167          2              134.0  toyota       gas        std          two
# 168          2              134.0  toyota       gas        std          two
# 169          2              134.0  toyota       gas        std          two
# 170          2              134.0  toyota       gas        std          two
# 171          2              134.0  toyota       gas        std          two
# 172          2              134.0  toyota       gas        std          two
# 173         -1               65.0  toyota       gas        std         four
# 174         -1               65.0  toyota    diesel      turbo         four
# 175         -1               65.0  toyota       gas        std         four
# 176         -1               65.0  toyota       gas        std         four
# 177         -1               65.0  toyota       gas        std         four
# 178          3              197.0  toyota       gas        std          two
# 179          3              197.0  toyota       gas        std          two
# 180         -1               90.0  toyota       gas        std         four
# 181         -1                0.0  toyota       gas        std         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 150    hatchback          fwd           front        95.7  ...           92
# 151    hatchback          fwd           front        95.7  ...           92
# 152    hatchback          fwd           front        95.7  ...           92
# 153        wagon          fwd           front        95.7  ...           92
# 154        wagon          4wd           front        95.7  ...           92
# 155        wagon          4wd           front        95.7  ...           92
# 156        sedan          fwd           front        95.7  ...           98
# 157    hatchback          fwd           front        95.7  ...           98
# 158        sedan          fwd           front        95.7  ...          110
# 159    hatchback          fwd           front        95.7  ...          110
# 160        sedan          fwd           front        95.7  ...           98
# 161    hatchback          fwd           front        95.7  ...           98
# 162        sedan          fwd           front        95.7  ...           98
# 163        sedan          rwd           front        94.5  ...           98
# 164    hatchback          rwd           front        94.5  ...           98
# 165        sedan          rwd           front        94.5  ...           98
# 166    hatchback          rwd           front        94.5  ...           98
# 167      hardtop          rwd           front        98.4  ...          146
# 168      hardtop          rwd           front        98.4  ...          146
# 169    hatchback          rwd           front        98.4  ...          146
# 170      hardtop          rwd           front        98.4  ...          146
# 171    hatchback          rwd           front        98.4  ...          146
# 172  convertible          rwd           front        98.4  ...          146
# 173        sedan          fwd           front       102.4  ...          122
# 174        sedan          fwd           front       102.4  ...          110
# 175    hatchback          fwd           front       102.4  ...          122
# 176        sedan          fwd           front       102.4  ...          122
# 177    hatchback          fwd           front       102.4  ...          122
# 178    hatchback          rwd           front       102.9  ...          171
# 179    hatchback          rwd           front       102.9  ...          171
# 180        sedan          rwd           front       104.5  ...          171
# 181        wagon          rwd           front       104.5  ...          161
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 150         2bbl  3.05    3.03               9.0       62.0    4800.0
# 151         2bbl  3.05    3.03               9.0       62.0    4800.0
# 152         2bbl  3.05    3.03               9.0       62.0    4800.0
# 153         2bbl  3.05    3.03               9.0       62.0    4800.0
# 154         2bbl  3.05    3.03               9.0       62.0    4800.0
# 155         2bbl  3.05    3.03               9.0       62.0    4800.0
# 156         2bbl  3.19    3.03               9.0       70.0    4800.0
# 157         2bbl  3.19    3.03               9.0       70.0    4800.0
# 158          idi  3.27    3.35              22.5       56.0    4500.0
# 159          idi  3.27    3.35              22.5       56.0    4500.0
# 160         2bbl  3.19    3.03               9.0       70.0    4800.0
# 161         2bbl  3.19    3.03               9.0       70.0    4800.0
# 162         2bbl  3.19    3.03               9.0       70.0    4800.0
# 163         2bbl  3.19    3.03               9.0       70.0    4800.0
# 164         2bbl  3.19    3.03               9.0       70.0    4800.0
# 165         mpfi  3.24    3.08               9.4      112.0    6600.0
# 166         mpfi  3.24    3.08               9.4      112.0    6600.0
# 167         mpfi  3.62    3.50               9.3      116.0    4800.0
# 168         mpfi  3.62    3.50               9.3      116.0    4800.0
# 169         mpfi  3.62    3.50               9.3      116.0    4800.0
# 170         mpfi  3.62    3.50               9.3      116.0    4800.0
# 171         mpfi  3.62    3.50               9.3      116.0    4800.0
# 172         mpfi  3.62    3.50               9.3      116.0    4800.0
# 173         mpfi  3.31    3.54               8.7       92.0    4200.0
# 174          idi  3.27    3.35              22.5       73.0    4500.0
# 175         mpfi  3.31    3.54               8.7       92.0    4200.0
# 176         mpfi  3.31    3.54               8.7       92.0    4200.0
# 177         mpfi  3.31    3.54               8.7       92.0    4200.0
# 178         mpfi  3.27    3.35               9.3      161.0    5200.0
# 179         mpfi  3.27    3.35               9.3      161.0    5200.0
# 180         mpfi  3.27    3.35               9.2      156.0    5200.0
# 181         mpfi  3.27    3.35               9.2      156.0    5200.0
#
#     city-mpg  highway-mpg  price
# 150       35           39   5348
# 151       31           38   6338
# 152       31           38   6488
# 153       31           37   6918
# 154       27           32   7898
# 155       27           32   8778
# 156       30           37   6938
# 157       30           37   7198
# 158       34           36   7898
# 159       38           47   7788
# 160       38           47   7738
# 161       28           34   8358
# 162       28           34   9258
# 163       29           34   8058
# 164       29           34   8238
# 165       26           29   9298
# 166       26           29   9538
# 167       24           30   8449
# 168       24           30   9639
# 169       24           30   9989
# 170       24           30  11199
# 171       24           30  11549
# 172       24           30  17669
# 173       29           34   8948
# 174       30           33  10698
# 175       27           32   9988
# 176       27           32  10898
# 177       27           32  11248
# 178       20           24  16558
# 179       19           24  15998
# 180       20           24  15690
# 181       19           24  15750
#
# [32 rows x 26 columns]

# %%
# Count total cars per company
df.make.value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
# Sort by price

df.sort_values(by=["price"],ascending=False)
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 74           1                0.0  mercedes-benz       gas        std
# 16           0                0.0            bmw       gas        std
# 73           0                0.0  mercedes-benz       gas        std
# 128          3                0.0        porsche       gas        std
# 17           0                0.0            bmw       gas        std
# ..         ...                ...            ...       ...        ...
# 138          2               83.0         subaru       gas        std
# 44           1                0.0          isuzu       gas        std
# 45           0                0.0          isuzu       gas        std
# 129          1                0.0        porsche       gas        std
# 9            0                0.0           audi       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 74           two      hardtop          rwd           front       112.0  ...
# 16           two        sedan          rwd           front       103.5  ...
# 73          four        sedan          rwd           front       120.9  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 17          four        sedan          rwd           front       110.0  ...
# ..           ...          ...          ...             ...         ...  ...
# 138          two    hatchback          fwd           front        93.7  ...
# 44           two        sedan          fwd           front        94.5  ...
# 45          four        sedan          fwd           front        94.5  ...
# 129          two    hatchback          rwd           front        98.4  ...
# 9            two    hatchback          4wd           front        99.5  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 74           304         mpfi  3.80    3.35               8.0      184.0
# 16           209         mpfi  3.62    3.39               8.0      182.0
# 73           308         mpfi  3.80    3.35               8.0      184.0
# 128          194         mpfi  3.74    2.90               9.5      207.0
# 17           209         mpfi  3.62    3.39               8.0      182.0
# ..           ...          ...   ...     ...               ...        ...
# 138           97         2bbl  3.62    2.36               9.0       69.0
# 44            90         2bbl  3.03    3.11               9.6       70.0
# 45            90         2bbl  3.03    3.11               9.6       70.0
# 129          203         mpfi  3.94    3.11              10.0      288.0
# 9            131         mpfi  3.13    3.40               7.0      160.0
#
#      peak-rpm city-mpg  highway-mpg  price
# 74     4500.0       14           16  45400
# 16     5400.0       16           22  41315
# 73     4500.0       14           16  40960
# 128    5900.0       17           25  37028
# 17     5400.0       15           20  36880
# ..        ...      ...          ...    ...
# 138    4900.0       31           36   5118
# 44     5400.0       38           43      0
# 45     5400.0       38           43      0
# 129    5750.0       17           28      0
# 9      5500.0       16           22      0
#
# [205 rows x 26 columns]

# %%
df.isin(["?"]).any().any()
# Out:
# False

# %%
#  Find each company’s Highest price car

companies = list(set(df.make.values))
for company in companies:
    comp_max_price = df[df["make"]==company].price.max()
    print(df[df["price"]==comp_max_price],"\n")
# Out:
#      symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 137          2              104.0  saab       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 137      sedan          fwd           front        99.1  ...          121
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 137         mpfi  3.54    3.07               9.0      160.0    5500.0
#
#     city-mpg  highway-mpg  price
# 137       19           26  18620
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 204         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg  price
# 204       19           25  22625
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 117          0              161.0  peugot       gas      turbo         four
# 136          3              150.0    saab       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 117      sedan          rwd           front       108.0  ...          134
# 136  hatchback          fwd           front        99.1  ...          121
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 117         mpfi  3.61    3.21               7.0      142.0    5600.0
# 136         mpfi  3.54    3.07               9.0      160.0    5500.0
#
#     city-mpg  highway-mpg  price
# 117       18           24  18150
# 136       19           26  18150
#
# [2 rows x 26 columns]
#
#     symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 49          0                0.0  jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 49      sedan          rwd           front       102.0  ...          326
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 49         mpfi  3.54    2.76              11.5      262.0    5000.0       13
#
#     highway-mpg  price
# 49           17  36000
#
# [1 rows x 26 columns]
#
#    symboling  normalized-losses         make fuel-type aspiration  \
# 1          3                0.0  alfa-romero       gas        std
# 2          1                0.0  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
#
#    peak-rpm city-mpg  highway-mpg  price
# 1    5000.0       21           27  16500
# 2    5000.0       19           26  16500
#
# [2 rows x 26 columns]
#
#     symboling  normalized-losses        make fuel-type aspiration  \
# 83          3                0.0  mitsubishi       gas      turbo
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 83          two  hatchback          fwd           front        95.9  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 83          156         spdi  3.59    3.86               7.0      145.0
#
#     peak-rpm city-mpg  highway-mpg  price
# 83    5000.0       19           24  14869
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 75          1                0.0  mercury       gas      turbo          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 75  hatchback          rwd           front       102.7  ...          140
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 75         mpfi  3.78    3.12               8.0      175.0    5000.0       19
#
#     highway-mpg  price
# 75           24  16503
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 105          3              194.0  nissan       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 105  hatchback          rwd           front        91.3  ...          181
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 105         mpfi  3.43    3.27               7.8      200.0    5200.0
#
#     city-mpg  highway-mpg  price
# 105       17           23  19699
#
# [1 rows x 26 columns]
#
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 8          1              158.0  audi       gas      turbo         four
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 8      sedan          fwd           front       105.8  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 8         mpfi  3.13     3.4               8.3      140.0    5500.0       17
#
#    highway-mpg  price
# 8           20  23875
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 66          0                0.0  mazda    diesel        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 66      sedan          rwd           front       104.9  ...          134
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 66          idi  3.43    3.64              22.0       72.0    4200.0       31
#
#     highway-mpg  price
# 66           39  18344
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 172          2              134.0  toyota       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 172  convertible          rwd           front        98.4  ...          146
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 172         mpfi  3.62     3.5               9.3      116.0    4800.0
#
#     city-mpg  highway-mpg  price
# 172       24           30  17669
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 149          0               85.0  subaru       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 149      wagon          4wd           front        96.9  ...          108
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 149         mpfi  3.62    2.64               7.7      111.0    4800.0
#
#     city-mpg  highway-mpg  price
# 149       23           23  11694
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 131          2                0.0  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 131  hatchback          fwd           front        96.1  ...          132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 131         mpfi  3.46     3.9               8.7        0.0       0.0
#
#     city-mpg  highway-mpg  price
# 131       23           31   9895
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses make fuel-type aspiration num-of-doors  \
# 16          0                0.0  bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 16      sedan          rwd           front       103.5  ...          209
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 16         mpfi  3.62    3.39               8.0      182.0    5400.0       16
#
#     highway-mpg  price
# 16           22  41315
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses      make fuel-type aspiration num-of-doors  \
# 124          3                0.0  plymouth       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 124  hatchback          rwd           front        95.9  ...          156
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 124         spdi  3.59    3.86               7.0      145.0    5000.0
#
#     city-mpg  highway-mpg  price
# 124       19           24  12764
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses        make fuel-type aspiration  \
# 192          0                0.0  volkswagen    diesel      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 192         four      sedan          fwd           front       100.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 192           97          idi  3.01     3.4              23.0       68.0
#
#      peak-rpm city-mpg  highway-mpg  price
# 192    4500.0       33           38  13845
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses           make fuel-type aspiration  \
# 74          1                0.0  mercedes-benz       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 74          two    hardtop          rwd           front       112.0  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 74          304         mpfi   3.8    3.35               8.0      184.0
#
#     peak-rpm city-mpg  highway-mpg  price
# 74    4500.0       14           16  45400
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 29          3              145.0  dodge       gas      turbo          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 29  hatchback          fwd           front        95.9  ...          156
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 29          mfi   3.6     3.9               7.0      145.0    5000.0       19
#
#     highway-mpg  price
# 29           24  12964
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 41          0               85.0  honda       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 41      sedan          fwd           front        96.5  ...          110
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 41         mpfi  3.15    3.58               9.0      101.0    5800.0       24
#
#     highway-mpg  price
# 41           28  12945
#
# [1 rows x 26 columns]
#
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 128          3                0.0  porsche       gas        std          two
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 128  convertible          rwd            rear        89.5  ...          194
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 128         mpfi  3.74     2.9               9.5      207.0    5900.0
#
#     city-mpg  highway-mpg  price
# 128       17           25  37028
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 20          0               81.0  chevrolet       gas        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 20      sedan          fwd           front        94.5  ...           90
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 20         2bbl  3.03    3.11               9.6       70.0    5400.0       38
#
#     highway-mpg  price
# 20           43   6575
#
# [1 rows x 26 columns]
#
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 46          2                0.0  isuzu       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 46  hatchback          rwd           front        96.0  ...          119
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 46         spfi  3.43    3.23               9.2       90.0    5000.0       24
#
#     highway-mpg  price
# 46           29  11048
#
# [1 rows x 26 columns]

# %%
df['price'].unique()
# Out:
# <bound method Series.unique of 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int64>

# %%
for col in df.columns:
    print(col,set(type(i) for i in df[col].unique()))
# Out:
# symboling {<class 'numpy.int64'>}
# normalized-losses {<class 'numpy.float64'>}
# make {<class 'str'>}
# fuel-type {<class 'str'>}
# aspiration {<class 'str'>}
# num-of-doors {<class 'str'>, <class 'int'>}
# body-style {<class 'str'>}
# drive-wheels {<class 'str'>}
# engine-location {<class 'str'>}
# wheel-base {<class 'numpy.float64'>}
# length {<class 'numpy.float64'>}
# width {<class 'numpy.float64'>}
# height {<class 'numpy.float64'>}
# curb-weight {<class 'numpy.int64'>}
# engine-type {<class 'str'>}
# num-of-cylinders {<class 'str'>}
# engine-size {<class 'numpy.int64'>}
# fuel-system {<class 'str'>}
# bore {<class 'numpy.float64'>}
# stroke {<class 'numpy.float64'>}
# compression-ratio {<class 'numpy.float64'>}
# horsepower {<class 'numpy.float64'>}
# peak-rpm {<class 'numpy.float64'>}
# city-mpg {<class 'numpy.int64'>}
# highway-mpg {<class 'numpy.int64'>}
# price {<class 'numpy.int64'>}

# %%
df['num-of-doors'].replace('two',2, inplace=True).replace('four',4, inplace = True)
# Out:
# /tmp/ipykernel_1197019/1426625948.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num-of-doors'].replace('two',2, inplace=True).replace('four',4, inplace = True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['num-of-doors'].replace('two',2, inplace=True).replace('four',4, inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
df['num-of-doors'].unique()
# Out:
# array(['two', 'four', 0], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
from collections import defaultdict
d = defaultdict(LabelEncoder)
def encoded(df,d):
    return df.apply(lambda x: d[x.name].fit_transform(x))
def decoded(df,d):
    return df.apply(lambda x: d[x.name].transform(x))
#le = preprocessing.LabelEncoder()
#df=df.apply(le.fit_transform,axis=0)
#df_str = df.select_dtypes(include=['O'])
#for col in df_str:
#    df[col] = le.fit_transform(list(df[col]))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

Y = df["price"]
X = encoded(df,d).drop(["price"],axis=1)
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.25, random_state = 42)

neigh = KNeighborsClassifier(n_neighbors=7)
neigh.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 174 uniques = sorted(uniques_set)
#     175 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 from sklearn.model_selection import train_test_split
#       4 Y = df["price"]
# ----> 5 X = encoded(df,d).drop(["price"],axis=1)
#       6 x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.25, random_state = 42)
#       8 neigh = KNeighborsClassifier(n_neighbors=7)
#
# Cell In[17], line 6, in encoded(df, d)
#       5 def encoded(df,d):
# ----> 6     return df.apply(lambda x: d[x.name].fit_transform(x))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:10361, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10347 from pandas.core.apply import frame_apply
#   10349 op = frame_apply(
#   10350     self,
#   10351     func=func,
#    (...)
#   10359     kwargs=kwargs,
#   10360 )
# > 10361 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[17], line 6, in encoded.<locals>.<lambda>(x)
#       5 def encoded(df,d):
# ----> 6     return df.apply(lambda x: d[x.name].fit_transform(x))
#
# File ~/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:115, in LabelEncoder.fit_transform(self, y)
#     102 """Fit label encoder and return encoded labels.
#     103
#     104 Parameters
#    (...)
#     112     Encoded labels.
#     113 """
#     114 y = column_or_1d(y, warn=True)
# --> 115 self.classes_, y = _unique(y, return_inverse=True)
#     116 return y
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_encode.py:42, in _unique(values, return_inverse, return_counts)
#      11 """Helper function to find unique values with support for python objects.
#      12
#      13 Uses pure python method for object dtype, and numpy method for
#    (...)
#      39     array. Only provided if `return_counts` is True.
#      40 """
#      41 if values.dtype == object:
# ---> 42     return _unique_python(
#      43         values, return_inverse=return_inverse, return_counts=return_counts
#      44     )
#      45 # numerical
#      46 return _unique_np(
#      47     values, return_inverse=return_inverse, return_counts=return_counts
#      48 )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_encode.py:179, in _unique_python(values, return_inverse, return_counts)
#     177 except TypeError:
#     178     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 179     raise TypeError(
#     180         "Encoders require their input argument must be uniformly "
#     181         f"strings or numbers. Got {types}"
#     182     )
#     183 ret = (uniques,)
#     185 if return_inverse:
#
# TypeError: Encoders require their input argument must be uniformly strings or numbers. Got ['int', 'str']

# %%
y_pred = neigh.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
